# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('results_seed42_ratio0.2_tree.csv')

# %%
df
# Out:
#       scenario target  sources  feature_count  ft_ratio  seed  \
# 0  D-1+D-3→D-2    D-2  D-1+D-3            114       0.2    42
# 1  D-1+D-3→D-2    D-2  D-1+D-3            114       0.2    42
# 2  D-1+D-2→D-3    D-3  D-1+D-2            114       0.2    42
# 3  D-1+D-2→D-3    D-3  D-1+D-2            114       0.2    42
# 4  D-2+D-3→D-1    D-1  D-2+D-3            114       0.2    42
# 5  D-2+D-3→D-1    D-1  D-2+D-3            114       0.2    42
#
#        split_strategy  fold_id  test_groups  split_seed  ...  \
# 0  stratified_shuffle        0          NaN          42  ...
# 1  stratified_shuffle        0          NaN          42  ...
# 2  stratified_shuffle        0          NaN          42  ...
# 3  stratified_shuffle        0          NaN          42  ...
# 4  stratified_shuffle        0          NaN          42  ...
# 5  stratified_shuffle        0          NaN          42  ...
#
#    pretrain_seconds  finetune_seconds  adapt_seconds  pretrain_epochs  \
# ...
